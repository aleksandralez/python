# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\lezon\\Downloads\\mieszkania_windows.csv")

# %%
df.head()
# Out:
#    Kwartal   Rok  Wartosc
# 0        4  2023     6386
# 1        3  2023     6335
# 2        2  2023     6134
# 3        1  2023     5668
# 4        4  2022     5708

# %%
dfy =df.groupby(df["Rok"])["Wartosc"].mean()

# %%
dfy
# Out:
# Rok
# 1998    1930.00
# 1999    2132.50
# 2000    2281.25
# 2001    2510.00
# 2002    2403.50
# 2003    2238.00
# 2004    2388.75
# 2005    2439.25
# 2006    2545.25
# 2007    2816.00
# 2008    3316.25
# 2009    3891.50
# 2010    4360.25
# 2011    3858.25
# 2012    3996.25
# 2013    4025.25
# 2014    4033.50
# 2015    3969.50
# 2016    4054.00
# 2017    4170.00
# 2018    4237.50
# 2019    4461.25
# 2020    4891.50
# 2021    5134.25
# 2022    5318.75
# 2023    6130.75
# Name: Wartosc, dtype: float64

# %%
pip install streamlit_jupyter
# Out:
# ...
#
# ...

# %%
import streamlit as st
from streamlit_jupyter import StreamlitPatcher, tqdm
StreamlitPatcher().jupyter()

# %%
#st.dataframe(dfy)
#TypeError: Unsupported type: <class 'pandas.core.series.Series'>, dataframe only accepts [<class 'pandas.core.frame.DataFrame'>]

# %%
#convert Series into DataFrame 
dfy_df = dfy.reset_index()

# %%
st.dataframe(dfy_df)
# Out:
#      Rok  Wartosc
# 0   1998  1930.00
# 1   1999  2132.50
# 2   2000  2281.25
# 3   2001  2510.00
# 4   2002  2403.50
# 5   2003  2238.00
# 6   2004  2388.75
# 7   2005  2439.25
# 8   2006  2545.25
# 9   2007  2816.00
# 10  2008  3316.25
# 11  2009  3891.50
# 12  2010  4360.25
# 13  2011  3858.25
# 14  2012  3996.25
# 15  2013  4025.25
# 16  2014  4033.50
# 17  2015  3969.50
# 18  2016  4054.00
# 19  2017  4170.00
# 20  2018  4237.50
# 21  2019  4461.25
# 22  2020  4891.50
# 23  2021  5134.25
# 24  2022  5318.75
# 25  2023  6130.75

# %%
#Save to file
# %%writefile streamlit_demo.py

import pandas as pd
import streamlit as st
from streamlit_jupyter import StreamlitPatcher, tqdm
StreamlitPatcher().jupyter()
df = pd.read_csv("C:\\Users\\lezon\\Downloads\\mieszkania_windows.csv")
dfy = df.groupby(df['Rok'])['Wartosc'].mean()
dfy_df = dfy.reset_index()

st.dataframe(dfy_df)
# Out:
# Overwriting streamlit_demo.py

# %% [markdown]
# ### executed in Terminal
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
